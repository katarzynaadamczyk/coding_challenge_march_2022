# %%
import pandas as pd

# %%
verblist = pd.read_csv('day4data.csv', sep=',')
verblist
# Out:
#            verb  count
# 0        append  48360
# 1           add  11626
# 2           put  10803
# 3        decode  10319
# 4         write   7416
# ..          ...    ...
# 798  prioritize      1
# 799       plain      1
# 800      ascend      1
# 801        time      1
# 802       tally      1
#
# [803 rows x 2 columns]

# %%
verblist = verblist.drop(columns=['count'])
verblist
# Out:
#            verb
# 0        append
# 1           add
# 2           put
# 3        decode
# 4         write
# ..          ...
# 798  prioritize
# 799       plain
# 800      ascend
# 801        time
# 802       tally
#
# [803 rows x 1 columns]

# %%
list(verblist['verb'])
# Out:
# ['append',
#  'add',
#  'put',
#  'decode',
#  'write',
#  'get',
#  'access',
#  'create',
#  'read',
#  'value',
#  'size',
#  'remove',
#  'fill',
#  'check',
#  'draw',
#  'do',
#  'char',
#  'print',
#  'close',
#  'paint',
#  'start',
#  'parse',
#  'clone',
#  'trace',
#  'equal',
#  'update',
#  'index',
#  'contain',
#  'position',
#  'debug',
#  'handle',
#  'reset',
#  'type',
#  'report',
#  'end',
#  'find',
#  'clear',
#  'load',
#  'line',
#  'log',
#  'format',
#  'make',
#  'class',
#  'encode',
#  'fire',
#  'insert',
#  'visit',
#  'dispose',
#  'translate',
#  'compare',
#  'process',
#  'copy',
#  'set',
#  'intern',
#  'register',
#  'match',
#  'default',
#  'install',
#  'invoke',
#  'flush',
#  'ensure',
#  'replace',
#  'skip',
#  'repaint',
#  'last',
#  'notify',
#  'convert',
#  'limit',
#  'trim',
#  'pop',
#  'peek',
#  'send',
#  'unlock',
#  'throw',
#  'push',
#  'fine',
#  'long',
#  'validate',
#  'localize',
#  'move',
#  'array',
#  'resolve',
# ...
